# %% [markdown]
# ### Bring in raw data and perform data cleaning
# **program:** 02_data_clean <br>
# **author:** chris chan<br>
# **date:** jan 27,2021<br>
# **desc:** Bring data in from postgres db and perform data cleaning <br>
#
# **datasources:**<br>
# - sb_analytic (balanced df thru 2010)
# - billboard analytic (hot 100 thru 2019)
# - spotify random (random thru 2020)

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_formats = ['svg']
# %matplotlib inline

plt.rcParams['figure.figsize'] = (9, 6)
sns.set(context='notebook', style='whitegrid', font_scale=1.2)

# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine('postgresql://chrischan:localhost@localhost:5432/m3spotify')

# %% [markdown]
# **1. billboard analytic**

# %%
query='SELECT * FROM bb_analytic;'
bbdf=pd.read_sql(query,engine)
bbdf.head(2)
# Out:
#                                               SongID                Performer  \
# 0                      AdictoTainy, Anuel AA & Ozuna  Tainy, Anuel AA & Ozuna
# 1  The Ones That Didn't Make It Back HomeJustin M...             Justin Moore
#
#                                      Song  \
# 0                                  Adicto
# 1  The Ones That Didn't Make It Back Home
#
#                                        spotify_genre        spotify_track_id  \
# 0                                  ['pop reggaeton']  3jbT1Y5MoPwEIpZndDDwVq
# 1  ['arkansas country', 'contemporary country', '...                    None
#
#   spotify_track_preview_url             spotify_track_album  \
# 0                      None  Adicto (with Anuel AA & Ozuna)
# 1                      None                            None
#
#   spotify_track_explicit  spotify_track_duration_ms  spotify_track_popularity  \
# 0                  False                   270740.0                      91.0
# 1                   None                        NaN                       NaN
#
#    ...  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0  ...    -4.803   0.0       0.0735         0.017          0.000016     0.179
# 1  ...       NaN   NaN          NaN           NaN               NaN       NaN
#
#    valence   tempo  time_signature    year
# 0    0.623  80.002             4.0  2019.0
# 1      NaN     NaN             NaN  2019.0
#
# [2 rows x 23 columns]

# %%
bbdf.describe()
# Out:
#        spotify_track_duration_ms  spotify_track_popularity  danceability  \
# count               2.374300e+04              23743.000000  23680.000000
# mean                2.213628e+05                 40.546393      0.598318
# std                 6.811626e+04                 22.229914      0.152968
# min                 2.968800e+04                  0.000000      0.000000
# 25%                 1.754135e+05                 22.000000      0.497000
# 50%                 2.156130e+05                 42.000000      0.606000
# 75%                 2.541330e+05                 58.000000      0.707000
# max                 3.079157e+06                100.000000      0.988000
#
#              energy           key      loudness          mode   speechiness  \
# count  23680.000000  23680.000000  23680.000000  23680.000000  23680.000000
# mean       0.618100      5.239189     -8.712564      0.729688      0.071810
# std        0.200039      3.559710      3.612757      0.444131      0.080615
# min        0.000581      0.000000    -28.030000      0.000000      0.000000
# 25%        0.473000      2.000000    -11.103500      0.000000      0.032000
# 50%        0.634000      5.000000     -8.284500      1.000000      0.041000
# 75%        0.779000      8.000000     -5.890750      1.000000      0.066800
# max        0.997000     11.000000      2.291000      1.000000      0.951000
#
#        acousticness  instrumentalness      liveness       valence  \
# count  23680.000000      23680.000000  23680.000000  23680.000000
# mean       0.296040          0.033250      0.192632      0.605254
# std        0.282873          0.137815      0.159794      0.238211
# min        0.000003          0.000000      0.009670      0.000000
# 25%        0.046800          0.000000      0.090500      0.420000
# 50%        0.197000          0.000005      0.131000      0.627000
# 75%        0.513000          0.000497      0.249000      0.805000
# max        0.991000          0.982000      0.999000      0.991000
#
#               tempo  time_signature          year
# count  23680.000000    23680.000000  28489.000000
# mean     120.197978        3.930785   1985.364983
# std       28.002601        0.320845     18.726423
# min        0.000000        0.000000   1958.000000
# 25%       99.081250        4.000000   1969.000000
# 50%      118.772000        4.000000   1982.000000
# 75%      136.122000        4.000000   2002.000000
# max      241.009000        5.000000   2019.000000

# %%
bbdf.time_signature.value_counts(dropna=False)
# Out:
# 4.0    21879
# NaN     4812
# 3.0     1535
# 5.0      174
# 1.0       90
# 0.0        2
# Name: time_signature, dtype: int64

# %% [markdown]
# *We have ~4800 missing values. We will not impute therefore drop.*

# %%
bbdf.drop(['spotify_track_preview_url'], axis=1, inplace=True)

# %%
bbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28492 entries, 0 to 28491
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SongID                     28492 non-null  object
#  1   Performer                  28492 non-null  object
#  2   Song                       28492 non-null  object
#  3   spotify_genre              27260 non-null  object
#  4   spotify_track_id           23743 non-null  object
#  5   spotify_track_album        23737 non-null  object
#  6   spotify_track_explicit     23743 non-null  object
#  7   spotify_track_duration_ms  23743 non-null  float64
#  8   spotify_track_popularity   23743 non-null  float64
#  9   danceability               23680 non-null  float64
#  10  energy                     23680 non-null  float64
#  11  key                        23680 non-null  float64
#  12  loudness                   23680 non-null  float64
#  13  mode                       23680 non-null  float64
#  14  speechiness                23680 non-null  float64
#  15  acousticness               23680 non-null  float64
#  16  instrumentalness           23680 non-null  float64
#  17  liveness                   23680 non-null  float64
#  18  valence                    23680 non-null  float64
#  19  tempo                      23680 non-null  float64
#  20  time_signature             23680 non-null  float64
#  21  year                       28489 non-null  float64
# dtypes: float64(15), object(7)
# memory usage: 4.8+ MB

# %% [markdown]
# *Drop duplicates*

# %%
bbdf = bbdf.drop_duplicates()
bbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 28470 entries, 0 to 28491
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SongID                     28470 non-null  object
#  1   Performer                  28470 non-null  object
#  2   Song                       28470 non-null  object
#  3   spotify_genre              27242 non-null  object
#  4   spotify_track_id           23729 non-null  object
#  5   spotify_track_album        23723 non-null  object
#  6   spotify_track_explicit     23729 non-null  object
#  7   spotify_track_duration_ms  23729 non-null  float64
#  8   spotify_track_popularity   23729 non-null  float64
#  9   danceability               23666 non-null  float64
#  10  energy                     23666 non-null  float64
#  11  key                        23666 non-null  float64
#  12  loudness                   23666 non-null  float64
#  13  mode                       23666 non-null  float64
#  14  speechiness                23666 non-null  float64
#  15  acousticness               23666 non-null  float64
#  16  instrumentalness           23666 non-null  float64
#  17  liveness                   23666 non-null  float64
#  18  valence                    23666 non-null  float64
#  19  tempo                      23666 non-null  float64
#  20  time_signature             23666 non-null  float64
#  21  year                       28467 non-null  float64
# dtypes: float64(15), object(7)
# memory usage: 5.0+ MB

# %%
bbdf['track_seconds'] = bbdf['spotify_track_duration_ms'] / 1000

# %%
bbdf.isnull().sum().sum()
#bbdf.isnull().values.any()
# Out:
# 87331

# %%
bbdf = bbdf[bbdf['time_signature'].notna()]

# %%
bbdf = bbdf[bbdf['track_seconds'].notna()]

# %% [markdown]
# **REMoving track that is extremely long (not bb 100)**

# %%
bbdf = bbdf[bbdf['spotify_track_id'] != '39FgoYSPntDNk6vqbwKRKH']

# %%
bbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23661 entries, 0 to 28491
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SongID                     23661 non-null  object
#  1   Performer                  23661 non-null  object
#  2   Song                       23661 non-null  object
#  3   spotify_genre              23550 non-null  object
#  4   spotify_track_id           23661 non-null  object
#  5   spotify_track_album        23655 non-null  object
#  6   spotify_track_explicit     23661 non-null  object
#  7   spotify_track_duration_ms  23661 non-null  float64
#  8   spotify_track_popularity   23661 non-null  float64
#  9   danceability               23661 non-null  float64
#  10  energy                     23661 non-null  float64
#  11  key                        23661 non-null  float64
#  12  loudness                   23661 non-null  float64
#  13  mode                       23661 non-null  float64
#  14  speechiness                23661 non-null  float64
#  15  acousticness               23661 non-null  float64
#  16  instrumentalness           23661 non-null  float64
#  17  liveness                   23661 non-null  float64
#  18  valence                    23661 non-null  float64
#  19  tempo                      23661 non-null  float64
#  20  time_signature             23661 non-null  float64
#  21  year                       23660 non-null  float64
#  22  track_seconds              23661 non-null  float64
# dtypes: float64(16), object(7)
# memory usage: 4.3+ MB

# %% [markdown]
# **2. Save Dataframe for analysis**

# %%
bbdf.to_csv(r'../data/clean/bbdf_clean.csv', index = False, header=True)
print(bbdf)
# Out:
#                                                   SongID  \
# 0                          AdictoTainy, Anuel AA & Ozuna
# 2                      ShallowLady Gaga & Bradley Cooper
# 3                    EnemiesPost Malone Featuring DaBaby
# 4        Bacc At It AgainYella Beezy, Gucci Mane & Quavo
# 5                                 The ArcherTaylor Swift
# ...                                                  ...
# 28486                   Tonight, Tonight, TonightGenesis
# 28487              Tonight, TonightThe Smashing Pumpkins
# 28488  Tonight's The Night (Gonna Be Alright)Rod Stewart
# 28489                     Tonight's The NightBLACKstreet
# 28491                   Tonight's The NightSolomon Burke
#
#                              Performer  \
# 0              Tainy, Anuel AA & Ozuna
# 2           Lady Gaga & Bradley Cooper
# 3         Post Malone Featuring DaBaby
# 4      Yella Beezy, Gucci Mane & Quavo
# 5                         Taylor Swift
# ...                                ...
# 28486                          Genesis
# 28487            The Smashing Pumpkins
# 28488                      Rod Stewart
# 28489                      BLACKstreet
# 28491                    Solomon Burke
#
#                                          Song  \
# 0                                      Adicto
# 2                                     Shallow
# 3                                     Enemies
# 4                            Bacc At It Again
# 5                                  The Archer
# ...                                       ...
# 28486               Tonight, Tonight, Tonight
# 28487                        Tonight, Tonight
# 28488  Tonight's The Night (Gonna Be Alright)
# 28489                     Tonight's The Night
# 28491                     Tonight's The Night
#
#                                            spotify_genre  \
# 0                                      ['pop reggaeton']
# 2                                   ['dance pop', 'pop']
# 3                      ['dfw rap', 'melodic rap', 'rap']
# 4         ['dfw rap', 'rap', 'southern hip hop', 'trap']
# 5                  ['dance pop', 'pop', 'post-teen pop']
# ...                                                  ...
# 28486  ['album rock', 'art rock', 'classic rock', 'me...
# 28487  ['alternative metal', 'alternative rock', 'gru...
# 28488    ['adult standards', 'mellow gold', 'soft rock']
# 28489  ['boy band', 'dance pop', 'hip hop', 'hip pop'...
# 28491  ['brill building pop', 'classic soul', 'funk',...
#
#              spotify_track_id  \
# 0      3jbT1Y5MoPwEIpZndDDwVq
# 2      2VxeLyX666F8uXCJ0dZF8B
# 3      0Xek5rqai2jcOWCYWJfVCF
# 4      2biNa12dMbHJrHVFRt8JyO
# 5      3pHkh7d0lzM2AldUtz2x37
# ...                       ...
# 28486  3qmYlsTbC9CD9SGoVmaEDa
# 28487  7bu0znpSbTks0O6I98ij0W
# 28488  10LRRKPmx8uHcSxLVWK0ct
# 28489  3scEwKiAkfdPUdZ6k1AEoW
# 28491  18TM70njJRFH4Fm4ZuwLd8
#
#                                      spotify_track_album  \
# 0                         Adicto (with Anuel AA & Ozuna)
# 2                              A Star Is Born Soundtrack
# 3                                   Hollywood's Bleeding
# 4                                       Bacc At It Again
# 5                                                  Lover
# ...                                                  ...
# 28486                                    Invisible Touch
# 28487  Mellon Collie And The Infinite Sadness (Deluxe...
# 28488               A Night on the Town (Deluxe Edition)
# 28489                                        Blackstreet
# 28491                     The Very Best Of Solomon Burke
#
#       spotify_track_explicit  spotify_track_duration_ms  \
# 0                      False                   270740.0
# 2                      False                   215733.0
# 3                       True                   196760.0
# 4                       True                   228185.0
# 5                      False                   211240.0
# ...                      ...                        ...
# 28486                  False                   530560.0
# 28487                  False                   254626.0
# 28488                  False                   237120.0
# 28489                  False                   258026.0
# 28491                  False                   161186.0
#
#        spotify_track_popularity  danceability  ...  mode  speechiness  \
# 0                          91.0         0.734  ...   0.0       0.0735
# 2                          88.0         0.572  ...   1.0       0.0308
# 3                          86.0         0.542  ...   1.0       0.2100
# 4                          61.0         0.948  ...   0.0       0.1680
# 5                          76.0         0.292  ...   1.0       0.0401
# ...                         ...           ...  ...   ...          ...
# 28486                      42.0         0.571  ...   1.0       0.0303
# 28487                      69.0         0.287  ...   1.0       0.0368
# 28488                      55.0         0.550  ...   1.0       0.0523
# 28489                      32.0         0.585  ...   0.0       0.0759
# 28491                      28.0         0.318  ...   1.0       0.0290
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.017000          0.000016    0.1790    0.623   80.002
# 2          0.371000          0.000000    0.2310    0.323   95.799
# 3          0.058800          0.000000    0.0955    0.667   76.388
# 4          0.001240          0.000001    0.0716    0.856  135.979
# 5          0.120000          0.005690    0.0663    0.166  124.344
# ...             ...               ...       ...      ...      ...
# 28486      0.015800          0.014000    0.0849    0.316   98.058
# 28487      0.000063          0.748000    0.2370    0.222  148.928
# 28488      0.336000          0.125000    0.3820    0.724  136.542
# 28489      0.133000          0.000011    0.1730    0.591   76.060
# 28491      0.401000          0.000000    0.6000    0.633  173.305
#
#        time_signature    year  track_seconds
# 0                 4.0  2019.0        270.740
# 2                 4.0  2018.0        215.733
# 3                 4.0  2019.0        196.760
# 4                 4.0  2019.0        228.185
# 5                 4.0  2019.0        211.240
# ...               ...     ...            ...
# 28486             4.0  1987.0        530.560
# 28487             4.0  1996.0        254.626
# 28488             3.0  1976.0        237.120
# 28489             4.0  1995.0        258.026
# 28491             3.0  1965.0        161.186
#
# [23661 rows x 23 columns]

# %% [markdown]
# ### Work with Spotify & BB hot 100

# %% [markdown]
# **1b. sb analytic**

# %%
query='SELECT * FROM sb_analytic;'
sbdf=pd.read_sql(query,engine)
sbdf.head(2)
# Out:
#                 SpotifyID  danceability  energy  key  mode  speechiness  \
# 0  285pBltuF7vW8TeWk8hdRR         0.511   0.566    6     0         0.20
# 1  7dt6x5M1jzdTEt8oCbisTK         0.680   0.578   10     1         0.04
#
#    acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# 0         0.349               0.0     0.340    0.218   83.903       239836
# 1         0.331               0.0     0.135    0.341  145.038       231267
#
#    loudness  is_hit    year
# 0    -7.230       1  2018.0
# 1    -5.804       1  2018.0

# %%
sbdf.describe()
# Out:
#        danceability        energy           key          mode   speechiness  \
# count  14682.000000  14682.000000  14682.000000  14682.000000  14682.000000
# mean      -0.079946     -0.029549      4.609249     -0.006266     -0.583123
# std       26.080135     26.081806     26.443567     26.085725     26.066713
# min     -999.000000   -999.000000   -999.000000   -999.000000   -999.000000
# 25%        0.497000      0.510000      2.000000      0.000000      0.034500
# 50%        0.614500      0.684000      6.000000      1.000000      0.049100
# 75%        0.722000      0.823000      8.000000      1.000000      0.105000
# max        0.986000      1.000000     11.000000      1.000000      0.956000
#
#        acousticness  instrumentalness      liveness       valence  \
# count  14682.000000      14682.000000  14682.000000  14682.000000
# mean      -0.448552         -0.595446     -0.482371     -0.155506
# std       26.071495         26.067194     26.069647     26.078774
# min     -999.000000       -999.000000   -999.000000   -999.000000
# 25%        0.017500          0.000000      0.092900      0.330000
# 50%        0.098350          0.000005      0.129000      0.530000
# 75%        0.358750          0.001650      0.258000      0.724000
# max        0.996000          0.991000      0.997000      0.992000
#
#               tempo   duration_ms      loudness        is_hit          year
# count  14682.000000  1.468200e+04  14682.000000  14682.000000  14038.000000
# mean     119.871835  2.404064e+05     -8.447724      0.630568   2004.446787
# std       41.763557  9.077982e+04     26.180325      0.482667      7.887024
# min     -999.000000 -9.990000e+02   -999.000000      0.000000   1958.000000
# 25%       96.985250  2.004922e+05     -9.451500      0.000000   1999.000000
# 50%      119.770500  2.316930e+05     -6.815000      1.000000   2005.000000
# 75%      139.841250  2.686000e+05     -5.084250      1.000000   2010.000000
# max      245.941000  4.802553e+06      0.316000      1.000000   2019.000000

# %%
sbdf.is_hit.value_counts(dropna=False)
# Out:
# 1    9258
# 0    5424
# Name: is_hit, dtype: int64

# %% [markdown]
# *We have ~4800 missing values. We will not impute therefore drop.*

# %%
sbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14682 entries, 0 to 14681
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SpotifyID         14682 non-null  object
#  1   danceability      14682 non-null  float64
#  2   energy            14682 non-null  float64
#  3   key               14682 non-null  int64
#  4   mode              14682 non-null  int64
#  5   speechiness       14682 non-null  float64
#  6   acousticness      14682 non-null  float64
#  7   instrumentalness  14682 non-null  float64
#  8   liveness          14682 non-null  float64
#  9   valence           14682 non-null  float64
#  10  tempo             14682 non-null  float64
#  11  duration_ms       14682 non-null  int64
#  12  loudness          14682 non-null  float64
#  13  is_hit            14682 non-null  int64
#  14  year              14038 non-null  float64
# dtypes: float64(10), int64(4), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# *Drop duplicates*

# %%
sbdf = sbdf.drop_duplicates()
sbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14682 entries, 0 to 14681
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SpotifyID         14682 non-null  object
#  1   danceability      14682 non-null  float64
#  2   energy            14682 non-null  float64
#  3   key               14682 non-null  int64
#  4   mode              14682 non-null  int64
#  5   speechiness       14682 non-null  float64
#  6   acousticness      14682 non-null  float64
#  7   instrumentalness  14682 non-null  float64
#  8   liveness          14682 non-null  float64
#  9   valence           14682 non-null  float64
#  10  tempo             14682 non-null  float64
#  11  duration_ms       14682 non-null  int64
#  12  loudness          14682 non-null  float64
#  13  is_hit            14682 non-null  int64
#  14  year              14038 non-null  float64
# dtypes: float64(10), int64(4), object(1)
# memory usage: 1.8+ MB

# %%
sbdf.isnull().sum().sum()
#bbdf.isnull().values.any()
# Out:
# 644

# %%
sbdf = sbdf[sbdf['year'].notna()]

# %%
sbdf = sbdf[sbdf['SpotifyID'] != '39FgoYSPntDNk6vqbwKRKH']

# %%
sbdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14037 entries, 0 to 14681
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SpotifyID         14037 non-null  object
#  1   danceability      14037 non-null  float64
#  2   energy            14037 non-null  float64
#  3   key               14037 non-null  int64
#  4   mode              14037 non-null  int64
#  5   speechiness       14037 non-null  float64
#  6   acousticness      14037 non-null  float64
#  7   instrumentalness  14037 non-null  float64
#  8   liveness          14037 non-null  float64
#  9   valence           14037 non-null  float64
#  10  tempo             14037 non-null  float64
#  11  duration_ms       14037 non-null  int64
#  12  loudness          14037 non-null  float64
#  13  is_hit            14037 non-null  int64
#  14  year              14037 non-null  float64
# dtypes: float64(10), int64(4), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# **2. Save Dataframe for analysis**

# %%
sbdf.to_csv(r'../data/clean/sbdf_clean.csv', index = False, header=True)
print(sbdf)
# Out:
#                     SpotifyID  danceability  energy  key  mode  speechiness  \
# 0      285pBltuF7vW8TeWk8hdRR         0.511   0.566    6     0       0.2000
# 1      7dt6x5M1jzdTEt8oCbisTK         0.680   0.578   10     1       0.0400
# 2      78QR3Wp35dqAhFEc2qAGjE         0.897   0.662    1     0       0.2920
# 3      2xLMifQCjDGFmkHkpNLD9h         0.834   0.730    8     1       0.2220
# 4      2iUXsYOEPhVqEBwsqP70rE         0.596   0.854    7     0       0.4630
# ...                       ...           ...     ...  ...   ...          ...
# 14677  7xV2k7FEMtUT4IUu4L87it         0.562   0.525    9     1       0.0283
# 14678  3e0tyTV5FiV1bcYeRjdDz2         0.404   0.636    4     0       0.0325
# 14679  2CQwzG5nbS7ys8CHSlavVg         0.406   0.895    2     0       0.0563
# 14680  0MS1NrmBWaCpPLFEXV0VMZ         0.329   0.963    4     1       0.1450
# 14681  62wqW6Q9eTozrruWPt9Z9i         0.194   0.251    8     1       0.0371
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 0          0.349000          0.000000    0.3400   0.2180   83.903
# 1          0.331000          0.000000    0.1350   0.3410  145.038
# 2          0.085200          0.000000    0.5340   0.3890  112.511
# 3          0.005130          0.000000    0.1240   0.4460  155.008
# 4          0.016900          0.000000    0.1240   0.1520  120.274
# ...             ...               ...       ...      ...      ...
# 14677      0.456000          0.883000    0.3110   0.7130  141.957
# 14678      0.064300          0.653000    0.0795   0.0979  140.105
# 14679      0.000429          0.000033    0.1200   0.2780  150.326
# 14680      0.000019          0.001380    0.2220   0.2050  116.847
# 14681      0.944000          0.000000    0.0997   0.3100  179.310
#
#        duration_ms  loudness  is_hit    year
# 0           239836    -7.230       1  2018.0
# 1           231267    -5.804       1  2018.0
# 2           145543    -6.903       1  2019.0
# 3           312820    -3.714       1  2018.0
# 4           203418    -5.114       1  2018.0
# ...            ...       ...     ...     ...
# 14677       314533   -14.594       0  1996.0
# 14678       386333    -8.798       0  1998.0
# 14679       209693    -5.282       0  2005.0
# 14680       179413    -3.501       0  2006.0
# 14681       169333   -12.959       0  1998.0
#
# [14037 rows x 15 columns]
